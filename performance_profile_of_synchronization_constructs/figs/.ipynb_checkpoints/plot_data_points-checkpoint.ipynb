# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15 , 10)
sns.set_style('darkgrid')

# %%
# plotting speedup
thd_cnt = [2 , 4, 6 ,8]
size_of_arr = [100000, 1000000, 10000000]

mutex_speedup = np.array([ [2.503,1.000,2.217,1.820] , 
                  [1.806,2.270,2.409,2.533] , 
                  [1.766,2.210,2.113,2.193] ])

busy_wait_speedup = np.array([ [2.501,2.011,1.845,0.0872] , 
                      [1.614,2.150,1.265,0.543] , 
                      [1.698,2.092,1.851,1.490] ])

cv_speedup = np.array([[2.233,2.343,1.839,1.534] , 
              [1.772,1.823,1.736,1.696] , 
              [1.779,1.827,1.875,1.875] ])

# %%
f , ax = plt.subplots(2,2)

ax[0,0].plot()
ax[0,0].set_title("Thread Count: {}".format(thd_cnt[0]))

ax[0,1].plot()
ax[0,1].set_title("Thread Count: {}".format(thd_cnt[1]))

ax[1,0].plot()
ax[1,0].set_title("Thread Count: {}".format(thd_cnt[2]))

ax[1,1].plot()
ax[1,1].set_title("Thread Count: {}".format(thd_cnt[3]))
# Out:
# Text(0.5,1,'Thread Count: 8')
